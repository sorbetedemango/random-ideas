# %%
import pandas as pd 
import matplotlib.pyplot as plt
import re


class Pokemon:
    def __init__(self,tipo,tipo2):
        self.tipo = tipo
        self.tipo2 = tipo2
class Analisis:
    def __init__(self):
        self.tipo = []
        
    def tipos(self,movimiento,otro):
        #movimiento es un pokemon, otro es otro pokemon xd
        efecto = 1
        
        if movimiento.tipo == "fuego":
            if otro.tipo == "agua" or otro.tipo == "roca" or otro.tipo == "dragón" or otro.tipo == "fuego" :
                efecto = 0.5
            elif otro.tipo == "acero" or otro.tipo == "bicho" or otro.tipo == "hielo" or otro.tipo == "planta":
                efecto = 2
        elif movimiento.tipo == "acero":
            if otro.tipo == "acero" or otro.tipo == "agua" or otro.tipo == "eléctrico" or otro.tipo == "fuego":
                efecto = 0.5
            elif otro.tipo == "hada" or otro.tipo == "hielo" or otro.tipo == "roca":
                efecto = 2
        elif movimiento.tipo == "bicho":
            if otro.tipo == "acero" or otro.tipo == "fantasma" or otro.tipo == "fuego" or otro.tipo == "hada" or otro.tipo == "lucha" or otro.tipo == "veneno" or otro.tipo == "volador":
                efecto = 0.5
            elif otro.tipo == "planta" or otro.tipo == "psíquico" or otro.tipo ==  "siniestro":
                efecto = 2
        elif movimiento.tipo == "dragón":
            if otro.tipo == "acero":
                efecto = 0.5
            elif otro.tipo == "dragón":
                efecto = 2
            elif otro.tipo == "hada":
                efecto = 0
        elif movimiento.tipo == "eléctrico":
            if otro.tipo == "agua" or otro.tipo ==  "volador":
                efecto = 2
            elif otro.tipo == "dragón"or otro.tipo ==  "eléctrico":
                efecto = 0.5
            elif otro.tipo == "tierra":
                efecto = 0
        elif movimiento.tipo == "fantasma":
            if otro.tipo == "fantasma" or otro.tipo == "psíquico":
                efecto = 2
            elif otro.tipo == "normal":
                efecto = 0
            elif otro.tipo == "siniestro":
                efecto = 0.5
        elif movimiento.tipo == "hada":
            if otro.tipo == "acero" or otro.tipo == "fuego" or otro.tipo == "veneno":
                efecto = 0.5
            elif otro.tipo == "dragón" or otro.tipo == "lucha" or otro.tipo == "siniestro":
                efecto = 2
        elif movimiento.tipo == "hielo":
            if otro.tipo == "acero" or otro.tipo == "agua" or otro.tipo == "fuego" or otro.tipo == "hielo":
                efecto = 0.5
            elif otro.tipo == "dragón" or otro.tipo == "planta" or otro.tipo == "tierra" or otro.tipo == "volador":
                efecto = 2
        elif movimiento.tipo == "lucha":
            if otro.tipo == "bicho" or otro.tipo == "hada" or otro.tipo == "psíquico" or otro.tipo == "veneno" or otro.tipo == "volador":
                efecto = 0.5
            elif otro.tipo == "acero" or otro.tipo == "hielo" or otro.tipo == "normal" or otro.tipo == "roca" or otro.tipo == "siniestro":
                efecto = 2
            elif otro.tipo == "fantasma":
                efecto = 0
        elif movimiento.tipo == "normal":
            if otro.tipo == "acero" or otro.tipo == "roca":
                efecto = 0.5
            elif otro.tipo == "fantasma":
                efecto = 0
        elif movimiento.tipo == "planta":
            if otro.tipo == "acero" or otro.tipo == "bicho" or otro.tipo == "dragón" or otro.tipo == "fuego" or otro.tipo == "planta" or otro.tipo == "veneno" or otro.tipo == "volador":
                efecto = 0.5
            elif otro.tipo == "agua" or otro.tipo == "roca" or otro.tipo == "tierra":
                efecto = 2
        elif movimiento.tipo == "psíquico":
            if otro.tipo == "acero" or otro.tipo == "psíquico":
                efecto = 0.5
            elif otro.tipo == "lucha" or otro.tipo == "veneno":
                efecto = 2
            elif otro.tipo == "siniestro":
                efecto = 0
        elif movimiento.tipo == "roca":
            if otro.tipo == "acero" or otro.tipo == "lucha" or otro.tipo == "tierra":
                efecto = 0.5
            elif otro.tipo == "bicho" or otro.tipo == "fuego" or otro.tipo == "hielo" or otro.tipo == "volador":
                efecto = 2
        elif movimiento.tipo == "siniestro":
            if otro.tipo == "hada" or otro.tipo == "lucha" or otro.tipo == "siniestro":
                efecto = 0.5
            elif otro.tipo == "fantasma" or otro.tipo == "psíquico":
                efecto = 2
        elif movimiento.tipo == "tierra":
            if otro.tipo == "bicho" or otro.tipo == "planta":
                efecto = 0.5
            elif otro.tipo == "acero" or otro.tipo == "eléctrico" or otro.tipo == "fuego" or otro.tipo == "roca" or otro.tipo == "veneno":
                efecto = 2
            elif otro.tipo == "volador":
                efecto = 0
        elif movimiento.tipo == "veneno":
            if otro.tipo == "fantasma" or otro.tipo == "roca" or otro.tipo == "tierra" or otro.tipo == "veneno":
                efecto = 0.5
            elif otro.tipo == "hada" or otro.tipo == "planta":
                efecto = 2
            elif otro.tipo == "acero":
                efecto = 0
        elif movimiento.tipo == "volador":
            if otro.tipo == "acero" or otro.tipo == "eléctrico" or otro.tipo == "roca":
                efecto = 0.5  
            elif otro.tipo == "bicho" or otro.tipo == "lucha" or otro.tipo == "planta":
                efecto = 2
        elif movimiento.tipo == "agua":
            if otro.tipo == "agua" or otro.tipo == "planta" or otro.tipo == "dragón":
                efecto = 0.5
            if otro.tipo == "fuego" or otro.tipo == "tierra" or otro.tipo == "roca":
                 efecto = 2
  
        
                 
        if movimiento.tipo == "fuego":
            if otro.tipo2 == "agua" or otro.tipo2 == "roca" or otro.tipo2 == "dragón" or otro.tipo2 == "fuego" :
                efecto *= 0.5
            elif otro.tipo2 == "acero" or otro.tipo2 == "bicho" or otro.tipo2 == "hielo" or otro.tipo2 == "planta":
                efecto *= 2
        elif movimiento.tipo == "acero":
            if otro.tipo2 == "acero" or otro.tipo2 == "agua" or otro.tipo2 == "eléctrico" or otro.tipo2 == "fuego":
                efecto *= 0.5
            elif otro.tipo2 == "hada" or otro.tipo2 == "hielo" or otro.tipo2 == "roca":
                efecto *= 2
        elif movimiento.tipo == "bicho":
            if otro.tipo2 == "acero" or otro.tipo2 == "fantasma" or otro.tipo2 == "fuego" or otro.tipo2 == "hada" or otro.tipo2 == "lucha" or otro.tipo2 == "veneno" or otro.tipo2 == "volador":
                efecto *= 0.5
            elif otro.tipo2 == "planta" or otro.tipo2 == "psíquico" or otro.tipo2 ==  "siniestro":
                efecto *= 2
        elif movimiento.tipo == "dragón":
            if otro.tipo2 == "acero":
                efecto *= 0.5
            elif otro.tipo2 == "dragón":
                efecto *= 2
            elif otro.tipo2 == "hada":
                efecto *= 0
        elif movimiento.tipo == "eléctrico":
            if otro.tipo2 == "agua" or otro.tipo2 ==  "volador":
                efecto *= 2
            elif otro.tipo2 == "dragón"or otro.tipo2 ==  "eléctrico":
                efecto *= 0.5
            elif otro.tipo2 == "tierra":
                efecto *= 0
        elif movimiento.tipo == "fantasma":
            if otro.tipo2 == "fantasma" or otro.tipo2 == "psíquico":
                efecto *= 2
            elif otro.tipo2 == "normal":
                efecto *= 0
            elif otro.tipo2 == "siniestro":
                efecto *= 0.5
        elif movimiento.tipo == "hada":
            if otro.tipo2 == "acero" or otro.tipo2 == "fuego" or otro.tipo2 == "veneno":
                efecto *= 0.5
            elif otro.tipo2 == "dragón" or otro.tipo2 == "lucha" or otro.tipo2 == "siniestro":
                efecto *= 2
        elif movimiento.tipo == "hielo":
            if otro.tipo2 == "acero" or otro.tipo2 == "agua" or otro.tipo2 == "fuego" or otro.tipo2 == "hielo":
                efecto *= 0.5
            elif otro.tipo2 == "dragón" or otro.tipo2 == "planta" or otro.tipo2 == "tierra" or otro.tipo2 == "volador":
                efecto *= 2
        elif movimiento.tipo == "lucha":
            if otro.tipo2 == "bicho" or otro.tipo2 == "hada" or otro.tipo2 == "psíquico" or otro.tipo2 == "veneno" or otro.tipo2 == "volador":
                efecto *= 0.5
            elif otro.tipo2 == "acero" or otro.tipo2 == "hielo" or otro.tipo2 == "normal" or otro.tipo2 == "roca" or otro.tipo2 == "siniestro":
                efecto *= 2
            elif otro.tipo2 == "fantasma":
                efecto *= 0
        elif movimiento.tipo == "normal":
            if otro.tipo2 == "acero" or otro.tipo2 == "roca":
                efecto *= 0.5
            elif otro.tipo2 == "fantasma":
                efecto *= 0
        elif movimiento.tipo == "planta":
            if otro.tipo2 == "acero" or otro.tipo2 == "bicho" or otro.tipo2 == "dragón" or otro.tipo2 == "fuego" or otro.tipo2 == "planta" or otro.tipo2 == "veneno" or otro.tipo2 == "volador":
                efecto *= 0.5
            elif otro.tipo2 == "agua" or otro.tipo2 == "roca" or otro.tipo2 == "tierra":
                efecto *= 2
        elif movimiento.tipo == "psíquico":
            if otro.tipo2 == "acero" or otro.tipo2 == "psíquico":
                efecto *= 0.5
            elif otro.tipo2 == "lucha" or otro.tipo2 == "veneno":
                efecto *= 2
            elif otro.tipo2 == "siniestro":
                efecto *= 0
        elif movimiento.tipo == "roca":
            if otro.tipo2 == "acero" or otro.tipo2 == "lucha" or otro.tipo2 == "tierra":
                efecto *= 0.5
            elif otro.tipo2 == "bicho" or otro.tipo2 == "fuego" or otro.tipo2 == "hielo" or otro.tipo2 == "volador":
                efecto *= 2
        elif movimiento.tipo == "siniestro":
            if otro.tipo2 == "hada" or otro.tipo2 == "lucha" or otro.tipo2 == "siniestro":
                efecto *= 0.5
            elif otro.tipo2 == "fantasma" or otro.tipo2 == "psíquico":
                efecto *= 2
        elif movimiento.tipo == "tierra":
            if otro.tipo2 == "bicho" or otro.tipo2 == "planta":
                efecto *= 0.5
            elif otro.tipo2 == "acero" or otro.tipo2 == "eléctrico" or otro.tipo2 == "fuego" or otro.tipo2 == "roca" or otro.tipo2 == "veneno":
                efecto *= 2
            elif otro.tipo2 == "volador":
                efecto *= 0
        elif movimiento.tipo == "veneno":
            if otro.tipo2 == "fantasma" or otro.tipo2 == "roca" or otro.tipo2 == "tierra" or otro.tipo2 == "veneno":
                efecto *= 0.5
            elif otro.tipo2 == "hada" or otro.tipo2 == "planta":
                efecto *= 2
            elif otro.tipo2 == "acero":
                efecto *= 0
        elif movimiento.tipo == "volador":
            if otro.tipo2 == "acero" or otro.tipo2 == "eléctrico" or otro.tipo2 == "roca":
                efecto *= 0.5  
            elif otro.tipo2 == "bicho" or otro.tipo2 == "lucha" or otro.tipo2 == "planta":
                efecto *= 2
        elif movimiento.tipo == "agua":
            if otro.tipo2 == "agua" or otro.tipo2 == "planta" or otro.tipo2 == "dragón":
                efecto *= 0.5
            if otro.tipo2 == "fuego" or otro.tipo2 == "tierra" or otro.tipo2 == "roca":
                 efecto *= 2
                 
        efecto2 = efecto
        efecto = 1
        
        if movimiento.tipo2 == "fuego":
            if otro.tipo == "agua" or otro.tipo == "roca" or otro.tipo == "dragón" or otro.tipo == "fuego" :
                efecto = 0.5
            elif otro.tipo == "acero" or otro.tipo == "bicho" or otro.tipo == "hielo" or otro.tipo == "planta":
                efecto = 2
        elif movimiento.tipo2 == "acero":
            if otro.tipo == "acero" or otro.tipo == "agua" or otro.tipo == "eléctrico" or otro.tipo == "fuego":
                efecto = 0.5
            elif otro.tipo == "hada" or otro.tipo == "hielo" or otro.tipo == "roca":
                efecto = 2
        elif movimiento.tipo2 == "bicho":
            if otro.tipo == "acero" or otro.tipo == "fantasma" or otro.tipo == "fuego" or otro.tipo == "hada" or otro.tipo == "lucha" or otro.tipo == "veneno" or otro.tipo == "volador":
                efecto = 0.5
            elif otro.tipo == "planta" or otro.tipo == "psíquico" or otro.tipo ==  "siniestro":
                efecto = 2
        elif movimiento.tipo2 == "dragón":
            if otro.tipo == "acero":
                efecto = 0.5
            elif otro.tipo == "dragón":
                efecto = 2
            elif otro.tipo == "hada":
                efecto = 0
        elif movimiento.tipo2 == "eléctrico":
            if otro.tipo == "agua" or otro.tipo ==  "volador":
                efecto = 2
            elif otro.tipo == "dragón"or otro.tipo ==  "eléctrico":
                efecto = 0.5
            elif otro.tipo == "tierra":
                efecto = 0
        elif movimiento.tipo2 == "fantasma":
            if otro.tipo == "fantasma" or otro.tipo == "psíquico":
                efecto = 2
            elif otro.tipo == "normal":
                efecto = 0
            elif otro.tipo == "siniestro":
                efecto = 0.5
        elif movimiento.tipo2 == "hada":
            if otro.tipo == "acero" or otro.tipo == "fuego" or otro.tipo == "veneno":
                efecto = 0.5
            elif otro.tipo == "dragón" or otro.tipo == "lucha" or otro.tipo == "siniestro":
                efecto = 2
        elif movimiento.tipo2 == "hielo":
            if otro.tipo == "acero" or otro.tipo == "agua" or otro.tipo == "fuego" or otro.tipo == "hielo":
                efecto = 0.5
            elif otro.tipo == "dragón" or otro.tipo == "planta" or otro.tipo == "tierra" or otro.tipo == "volador":
                efecto = 2
        elif movimiento.tipo2 == "lucha":
            if otro.tipo == "bicho" or otro.tipo == "hada" or otro.tipo == "psíquico" or otro.tipo == "veneno" or otro.tipo == "volador":
                efecto = 0.5
            elif otro.tipo == "acero" or otro.tipo == "hielo" or otro.tipo == "normal" or otro.tipo == "roca" or otro.tipo == "siniestro":
                efecto = 2
            elif otro.tipo == "fantasma":
                efecto = 0
        elif movimiento.tipo2 == "normal":
            if otro.tipo == "acero" or otro.tipo == "roca":
                efecto = 0.5
            elif otro.tipo == "fantasma":
                efecto = 0
        elif movimiento.tipo2 == "planta":
            if otro.tipo == "acero" or otro.tipo == "bicho" or otro.tipo == "dragón" or otro.tipo == "fuego" or otro.tipo == "planta" or otro.tipo == "veneno" or otro.tipo == "volador":
                efecto = 0.5
            elif otro.tipo == "agua" or otro.tipo == "roca" or otro.tipo == "tierra":
                efecto = 2
        elif movimiento.tipo2 == "psíquico":
            if otro.tipo == "acero" or otro.tipo == "psíquico":
                efecto = 0.5
            elif otro.tipo == "lucha" or otro.tipo == "veneno":
                efecto = 2
            elif otro.tipo == "siniestro":
                efecto = 0
        elif movimiento.tipo2 == "roca":
            if otro.tipo == "acero" or otro.tipo == "lucha" or otro.tipo == "tierra":
                efecto = 0.5
            elif otro.tipo == "bicho" or otro.tipo == "fuego" or otro.tipo == "hielo" or otro.tipo == "volador":
                efecto = 2
        elif movimiento.tipo2 == "siniestro":
            if otro.tipo == "hada" or otro.tipo == "lucha" or otro.tipo == "siniestro":
                efecto = 0.5
            elif otro.tipo == "fantasma" or otro.tipo == "psíquico":
                efecto = 2
        elif movimiento.tipo2 == "tierra":
            if otro.tipo == "bicho" or otro.tipo == "planta":
                efecto = 0.5
            elif otro.tipo == "acero" or otro.tipo == "eléctrico" or otro.tipo == "fuego" or otro.tipo == "roca" or otro.tipo == "veneno":
                efecto = 2
            elif otro.tipo == "volador":
                efecto = 0
        elif movimiento.tipo2 == "veneno":
            if otro.tipo == "fantasma" or otro.tipo == "roca" or otro.tipo == "tierra" or otro.tipo == "veneno":
                efecto = 0.5
            elif otro.tipo == "hada" or otro.tipo == "planta":
                efecto = 2
            elif otro.tipo == "acero":
                efecto = 0
        elif movimiento.tipo2 == "volador":
            if otro.tipo == "acero" or otro.tipo == "eléctrico" or otro.tipo == "roca":
                efecto = 0.5  
            elif otro.tipo == "bicho" or otro.tipo == "lucha" or otro.tipo == "planta":
                efecto = 2
        elif movimiento.tipo2 == "agua":
            if otro.tipo == "agua" or otro.tipo == "planta" or otro.tipo == "dragón":
                efecto = 0.5
            if otro.tipo == "fuego" or otro.tipo == "tierra" or otro.tipo == "roca":
                 efecto = 2
                 
        if movimiento.tipo2 == "fuego":
            if otro.tipo2 == "agua" or otro.tipo2 == "roca" or otro.tipo2 == "dragón" or otro.tipo2 == "fuego" :
                efecto *= 0.5
            elif otro.tipo2 == "acero" or otro.tipo2 == "bicho" or otro.tipo2 == "hielo" or otro.tipo2 == "planta":
                efecto *= 2
        elif movimiento.tipo2 == "acero":
            if otro.tipo2 == "acero" or otro.tipo2 == "agua" or otro.tipo2 == "eléctrico" or otro.tipo2 == "fuego":
                efecto *= 0.5
            elif otro.tipo2 == "hada" or otro.tipo2 == "hielo" or otro.tipo2 == "roca":
                efecto *= 2
        elif movimiento.tipo2 == "bicho":
            if otro.tipo2 == "acero" or otro.tipo2 == "fantasma" or otro.tipo2 == "fuego" or otro.tipo2 == "hada" or otro.tipo2 == "lucha" or otro.tipo2 == "veneno" or otro.tipo2 == "volador":
                efecto *= 0.5
            elif otro.tipo2 == "planta" or otro.tipo2 == "psíquico" or otro.tipo2 ==  "siniestro":
                efecto *= 2
        elif movimiento.tipo2 == "dragón":
            if otro.tipo2 == "acero":
                efecto *= 0.5
            elif otro.tipo2 == "dragón":
                efecto *= 2
            elif otro.tipo2 == "hada":
                efecto *= 0
        elif movimiento.tipo2 == "eléctrico":
            if otro.tipo2 == "agua" or otro.tipo2 ==  "volador":
                efecto *= 2
            elif otro.tipo2 == "dragón"or otro.tipo2 ==  "eléctrico":
                efecto *= 0.5
            elif otro.tipo2 == "tierra":
                efecto *= 0
        elif movimiento.tipo2 == "fantasma":
            if otro.tipo2 == "fantasma" or otro.tipo2 == "psíquico":
                efecto *= 2
            elif otro.tipo2 == "normal":
                efecto *= 0
            elif otro.tipo2 == "siniestro":
                efecto *= 0.5
        elif movimiento.tipo2 == "hada":
            if otro.tipo2 == "acero" or otro.tipo2 == "fuego" or otro.tipo2 == "veneno":
                efecto *= 0.5
            elif otro.tipo2 == "dragón" or otro.tipo2 == "lucha" or otro.tipo2 == "siniestro":
                efecto *= 2
        elif movimiento.tipo2 == "hielo":
            if otro.tipo2 == "acero" or otro.tipo2 == "agua" or otro.tipo2 == "fuego" or otro.tipo2 == "hielo":
                efecto *= 0.5
            elif otro.tipo2 == "dragón" or otro.tipo2 == "planta" or otro.tipo2 == "tierra" or otro.tipo2 == "volador":
                efecto *= 2
        elif movimiento.tipo2 == "lucha":
            if otro.tipo2 == "bicho" or otro.tipo2 == "hada" or otro.tipo2 == "psíquico" or otro.tipo2 == "veneno" or otro.tipo2 == "volador":
                efecto *= 0.5
            elif otro.tipo2 == "acero" or otro.tipo2 == "hielo" or otro.tipo2 == "normal" or otro.tipo2 == "roca" or otro.tipo2 == "siniestro":
                efecto *= 2
            elif otro.tipo2 == "fantasma":
                efecto *= 0
        elif movimiento.tipo2 == "normal":
            if otro.tipo2 == "acero" or otro.tipo2 == "roca":
                efecto *= 0.5
            elif otro.tipo2 == "fantasma":
                efecto *= 0
        elif movimiento.tipo2 == "planta":
            if otro.tipo2 == "acero" or otro.tipo2 == "bicho" or otro.tipo2 == "dragón" or otro.tipo2 == "fuego" or otro.tipo2 == "planta" or otro.tipo2 == "veneno" or otro.tipo2 == "volador":
                efecto *= 0.5
            elif otro.tipo2 == "agua" or otro.tipo2 == "roca" or otro.tipo2 == "tierra":
                efecto *= 2
        elif movimiento.tipo2 == "psíquico":
            if otro.tipo2 == "acero" or otro.tipo2 == "psíquico":
                efecto *= 0.5
            elif otro.tipo2 == "lucha" or otro.tipo2 == "veneno":
                efecto *= 2
            elif otro.tipo2 == "siniestro":
                efecto *= 0
        elif movimiento.tipo2 == "roca":
            if otro.tipo2 == "acero" or otro.tipo2 == "lucha" or otro.tipo2 == "tierra":
                efecto *= 0.5
            elif otro.tipo2 == "bicho" or otro.tipo2 == "fuego" or otro.tipo2 == "hielo" or otro.tipo2 == "volador":
                efecto *= 2
        elif movimiento.tipo2 == "siniestro":
            if otro.tipo2 == "hada" or otro.tipo2 == "lucha" or otro.tipo2 == "siniestro":
                efecto *= 0.5
            elif otro.tipo2 == "fantasma" or otro.tipo2 == "psíquico":
                efecto *= 2
        elif movimiento.tipo2 == "tierra":
            if otro.tipo2 == "bicho" or otro.tipo2 == "planta":
                efecto *= 0.5
            elif otro.tipo2 == "acero" or otro.tipo2 == "eléctrico" or otro.tipo2 == "fuego" or otro.tipo2 == "roca" or otro.tipo2 == "veneno":
                efecto *= 2
            elif otro.tipo2 == "volador":
                efecto *= 0
        elif movimiento.tipo2 == "veneno":
            if otro.tipo2 == "fantasma" or otro.tipo2 == "roca" or otro.tipo2 == "tierra" or otro.tipo2 == "veneno":
                efecto *= 0.5
            elif otro.tipo2 == "hada" or otro.tipo2 == "planta":
                efecto *= 2
            elif otro.tipo2 == "acero":
                efecto *= 0
        elif movimiento.tipo2 == "volador":
            if otro.tipo2 == "acero" or otro.tipo2 == "eléctrico" or otro.tipo2 == "roca":
                efecto *= 0.5  
            elif otro.tipo2 == "bicho" or otro.tipo2 == "lucha" or otro.tipo2 == "planta":
                efecto *= 2
        elif movimiento.tipo2 == "agua":
            if otro.tipo2 == "agua" or otro.tipo2 == "planta" or otro.tipo2 == "dragón":
                efecto *= 0.5
            if otro.tipo2 == "fuego" or otro.tipo2 == "tierra" or otro.tipo2 == "roca":
                 efecto *= 2
        if efecto2 > efecto:
            return efecto2*2 + efecto
        else:
            return efecto*2 + efecto2
        

b = Analisis()
lista =  ["fuego","acero","bicho","planta","dragón","eléctrico","fantasma","hada","hielo","lucha","normal","roca","psíquico","siniestro","veneno","tierra","volador","agua"]
lista2 = [] #lista con pokemons, 1 con cada combinación posible de tipos
lista0 = []

for tipo in lista:
    tipo1 = tipo
    for tipo in lista:
        if tipo1 == tipo:
            tipo2 = None
        else:
            tipo2 = tipo
        if (tipo2, tipo1) in lista0:
            pass
        else:
            lista0.append((tipo1,tipo2))
            
for tipo in lista0:
    tipo1,tipo2 = tipo        
    a = Pokemon(tipo1,tipo2)
    lista2.append(a)
        
        
lista3 = []  #lista con puntuación para cada pokemon según la efectividad de sus ataques
for pokemon in lista2:
    poke = pokemon
    p = 0
    for pokemon in lista2:
            p += b.tipos(poke,pokemon)
    lista3.append(p)
    
lista4 = [] #lista con todos los pokemons pero en lugar de su objeto, sus tipos
for pokemon in lista2:
    tipos = (f'{pokemon.tipo}, {pokemon.tipo2}')
    lista4.append(tipos)
    
s = pd.Series(lista3,index = lista4)
s

s1 =s.sort_values(ascending= True)
#fig,ax = plt.subplots(figsize = (500,200))
#ax.bar(s1.index,s1.values)

lista5 = [] #lista con puntuación para cada pokemon según la efectividad de sus defensas
for pokemon in lista2:
    poke = pokemon
    q = 0
    for pokemon in lista2:
        q += b.tipos(pokemon,poke)
    lista5.append(q)
    
s2 = pd.Series(lista5,index = lista4)

s3 =s2.sort_values(ascending= False)



#fig,ax = plt.subplots(figsize = (30,10))
#ax.bar(s3.index,s3.values)

dic = {}
for tipos in s3.index:
    dic[tipos] = 0

contador = 0
for p in s3.index: 
    try:
        contador += 1
        dic[p] += contador
    except:
        pass
    
contador = 0
for p in s1.index:
    if p in dic:
        contador += 1
        dic[p] += contador
       
    
#fig,ax = plt.subplots(figsize = (30,10))
lista6 = []
for a in dic:
    lista6.append(a)
lista7 = []
for a in dic.values():
    lista7.append(a) #crear dos listas con 1: tipos de cada pokemon y 2: puntuación total
#ax.bar(dic.index,dic.values)


s5= pd.Series(lista7,index = lista6)
print(s5)
#s5 = s4.sort_values(ascending= False)
s5
dic3 = {}
for elem in s5.index:
    dic3[elem] = s5[elem]
    
#df = pd.DataFrame([[key, dic[key]] for key in dic.keys()], columns=['tipo', 'puntuación'])
lista8 = []
for i in range(171):
    lista8.append(i+1)
df2 = s5.to_frame(name="puntuación")
df2.reset_index()
#df2.set_index("índice")

dic2 = {}

contador = 0
for tipos in s3.index:
    dic2[tipos] = 0
    
contador = 0    
for p in s3.index: 
    contador += 1
    dic2[p] += contador
    
    

dic3 = {}


for tipos in s3.index:   
    dic3[tipos] = 0

    
contador = 0
for p in s1.index:
    if p in dic3:
        contador += 1
        dic3[p] += contador
df2["poder defensivo"] = dic2.values()
df2["poder atacante"] = dic3.values()
df2["tipos"] = s5.index
df2["índice"] = lista8
df2.set_index("índice",inplace=True)
df2.reset_index()

def get_tipo1(tipos):
    
    items =  re.split(':|,| ', tipos)  # Lista con cada uno de los campos que componen la fecha por separado  
    return items[0]

def get_tipo2(tipos):
    
    items =  re.split(':|,| ', tipos)  # Lista con cada uno de los campos que componen la fecha por separado  
    return items[2]



df2['tipo1'] = df2["tipos"].map(get_tipo1)
df2['tipo2'] = df2["tipos"].map(get_tipo2)


lista10 = []
for tipo in lista:
    contador = 0
    contador2 = 0
    for row in df2["tipos"].values:
        if tipo in row:
            contador += df2.iloc[contador2]["puntuación"]
            pass
        contador2 += 1
    lista10.append(contador)

    
s6 = pd.Series(lista10,index = lista)
s7 = s6.sort_values(ascending = False) #serie con la puntuación individual de cada tipo en base a sus combinaciones


df2.sort_values(by="puntuación",ascending = False,inplace = True)
df2.reset_index(inplace = True)
pd.set_option('max_rows', None)
pd.set_option('max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)
df2.to_csv("combinaciones.tipos.csv")
df2.drop(columns = "índice",inplace = True)
a = {}
a["tipo1"] = []
for i in df2["tipo2"]:
    a["tipo1"].append(i)

a["puntuación"] =[]
for i in df2["puntuación"]:
    a["puntuación"].append(i)
nuevas_filas = pd.DataFrame(a)   
nuevas_filas
df3 = pd.concat([df2] + [nuevas_filas], ignore_index=True)
print(lista3)
df2
# Out:
# hielo, roca             165
# bicho, planta            19
# planta, hielo           100
# roca, tierra            175
# planta, psíquico         38
# bicho, hielo             95
# planta, siniestro        50
# hielo, siniestro        128
# planta, dragón           28
# planta, lucha            91
# roca, siniestro         143
# planta, volador          96
# fuego, roca             175
# bicho, volador           84
# normal, roca             78
# hielo, normal            65
# hielo, psíquico         124
# roca, psíquico          145
# hielo, volador          163
# hielo, lucha            181
# planta, tierra          151
# planta, hada             91
# lucha, roca             188
# dragón, lucha           106
# fuego, hielo            183
# hada, hielo             162
# bicho, lucha            106
# dragón, siniestro        57
# bicho, psíquico          73
# fantasma, psíquico       83
# roca, agua              188
# eléctrico, roca         148
# planta, normal           38
# ...

# %%
dicc = {}
for elemento in lista:
    dicc[elemento] = 0
dicc["None"] = 0
contador2 = 0
print(df2["puntuación"][contador2])
for elementos in df3["tipo1"]:
    dicc[elementos] += df3["puntuación"][contador2]
    contador2 += 1
a = pd.Series(dicc.values(),index =dicc.keys()).sort_values(ascending = False)
dfff = a.to_frame(name = "puntuacion")
fig, ax = plt.subplots(figsize = (20,10))
ax.bar(a.index,a.values)
dfff

#el análisis es el mismo, pero también se tiene en cuenta las combinaciones únicas, es decir, con None.
#con statgraphics, saco que la media es 3096, que es mayor que la puntuación de las combinaciones con None (2968) por lo que,
#sabiendo que la S es 706, el rango 2465 y la diferencia 128 puntos, podemos decir que los tipos combinados son más efectivos
#que sin combinar, pero no con una diferencia muy grande.
# Out:
# 320
#            puntuacion
# acero            4237
# tierra           4112
# fuego            3913
# agua             3883
# hada             3840
# fantasma         3475
# volador          3367
# lucha            3342
# eléctrico        3298
# roca             3013
# None             2968
# veneno           2802
# siniestro        2791
# hielo            2712
# psíquico         2382
# dragón           2309
# bicho            2305
# normal           2303
# planta           1772

# %%
lista =  ["fuego","acero","bicho","planta","dragón","eléctrico","fantasma","hada","hielo","lucha","normal","roca","psíquico","siniestro","veneno","tierra","volador","agua"]
lista2 = [] #lista con pokemons, 1 con cada combinación posible de tipos
lista0 = []

for tipo in lista:
    tipo1 = tipo
    for tipo in lista:
        if tipo1 == tipo:
            tipo2 = None
        else:
            tipo2 = tipo
        if (tipo2,tipo1) in lista0:
            pass
        else:
            lista0.append((tipo1,tipo2))
            
for tipo in lista0:
    tipo1,tipo2 = tipo        
    a = Pokemon(tipo1,tipo2)
    lista2.append(a)

# %%
dicc2 = {}
for elemento in lista:
    dicc2[elemento] = 0
contador = 0
for e in df2["tipo2"]:
    if e not in lista:
        q = df2["tipo1"][contador]
        dicc2[q] += df2["puntuación"][contador]   
    contador+=1
    
print(dicc2)
a = pd.Series(dicc2.values(),index=dicc2.keys()).sort_values(ascending=False)
fig,ax = plt.subplots(figsize=(20,10))
ax.bar(a.index,a.values)
ax.set_title("Puntuación de tipo según la puntuación de su combinación única (sin otro tipo)")
# Out:
# {'fuego': 224, 'acero': 222, 'bicho': 115, 'planta': 61, 'dragón': 118, 'eléctrico': 181, 'fantasma': 186, 'hada': 207, 'hielo': 143, 'lucha': 183, 'normal': 149, 'roca': 155, 'psíquico': 106, 'siniestro': 136, 'veneno': 157, 'tierra': 242, 'volador': 181, 'agua': 202}
# Text(0.5, 1.0, 'Puntuación de tipo según la puntuación de su combinación única (sin otro tipo)')

# %%
lista11 = []
for tipo in lista:
    contador = 0
    contador2 = 0
    for row in df2["tipos"].values:
        if tipo in row:
            contador += df2.iloc[contador2]["poder defensivo"]
            pass
        contador2 += 1
    lista11.append(contador)

    
s8 = pd.Series(lista11,index = lista)
s9 = s8.sort_values(ascending = False)

fig,ax = plt.subplots(figsize = (25,10))
ax.bar(s9.index,s9.values)
ax.set_title("Poder defensivo de cada tipo")
pass

# %%
lista12 = []
for tipo in lista:
    contador = 0
    contador2 = 0
    for row in df2["tipos"].values:
        if tipo in row:
            contador += df2.iloc[contador2]["poder atacante"]
            pass
        contador2 += 1
    lista12.append(contador)

    
s10 = pd.Series(lista12,index = lista)
s11 = s10.sort_values(ascending = False)
fig,ax = plt.subplots(figsize = (25,10))
ax.bar(s11.index,s11.values, color = "r")
ax.set_title("Poder atacante de cada tipo")
pass

# %%
df2
# Out:
#      puntuación  poder defensivo  poder atacante                 tipos  \
# 0           320              157             163         acero, tierra
# 1           290              162             128          acero, lucha
# 2           288              170             118        acero, volador
# 3           284              171             113           acero, hada
# 4           283              143             140            hada, agua
# 5           282              132             150           fuego, hada
# 6           281              121             160          tierra, agua
# 7           280              131             149           fuego, agua
# 8           280              113             167          hada, tierra
# 9           278              167             111           acero, agua
# 10          268              139             129          fuego, acero
# 11          265               96             169         fuego, tierra
# ...

# %%
df4 = df2.sort_values(by="poder defensivo", ascending = False)
pd.set_option('max_rows', None)
pd.set_option('max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)
print(df4.iloc[:,[0,1,2,3]])
# Out:
#      puntuación  poder defensivo  poder atacante                 tipos
# 3           284              171             113           acero, hada
# 2           288              170             118        acero, volador
# 32          223              169              54         acero, dragón
# 85          178              168              10      fantasma, normal
# 9           278              167             111           acero, agua
# 15          252              166              86       acero, fantasma
# 56          203              165              38   fantasma, siniestro
# 38          222              164              58           acero, None
# 60          199              163              36     siniestro, veneno
# 1           290              162             128          acero, lucha
# 36          222              161              61          acero, bicho
# 12          265              160             105        fantasma, hada
# ...

# %%
lista20 = []
for e in s7.index:
    lista20.append(e)
lista21 = []
for e in s9.values:
    lista21.append(e)
contador = 0
for e in s9.index:
    posicion = lista20.index(e)
    lista21[posicion] = s9.values[contador]
    contador += 1

lista22 = []
for e in s8.values:
    lista22.append(e)
    
contador = 0
for e in s11.index:
    posicion = lista20.index(e)
    lista22[posicion] = s11.values[contador]
    contador += 1   
fig,ax = plt.subplots(figsize = (25,10))
ax.bar(lista20,lista21, color = "b")
ax.bar(lista20,lista22,bottom = lista21,color = "r")
ax.grid(axis = "y")
ax.legend(["poder defensivo", "poder atacante"])
pass

# %%
s8.values[2]
# Out:
# 2724

# %%
def a(n,u):
    if n <= 0 or u <= 0:
        return 0
    else:
        return n + (a(n-2,u-1))
print(a(342,400))

def b(n,u):
    if n <= 0 or u <= 0:
        return 0
    else:
        return n + (b(n+2,u-1))
b(1,18)
# Out:
# 29412
# 324

# %%
def miguel(a,b):
    return a*b

# %%
miguel(2,3)
# Out:
# 6
